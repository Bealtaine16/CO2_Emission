# %%
import os
import pickle

import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping

from src.data_preparation.data_preprocessing import DataReshaperLSTM
from src.visualization.charts import ModelCharts
from src.visualization.metrics import PredictionEvaluator, GlobalResults
from src.config import Config

# %% [markdown]
# ## Load the data

# %%
config = Config()
variant_co2 = 'co2'

#lstm
train_lstm_df = pd.read_csv(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/train.csv')).set_index(["year", config.additional_index]).drop(columns=['country_order'])
test_lstm_df = pd.read_csv(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/test.csv')).set_index(["year", config.additional_index]).drop(columns=['country_order'])

with open(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/data_preprocessor_lstm.pkl'), 'rb') as f:
    data_preprocessor_lstm = pickle.load(f)

#arimax
train_arimax_pred_df = pd.read_csv(os.path.join(config.output_cleaned_hybrid, f'arimax_lstm/{variant_co2}/pca_arimax_pred_train.csv')).set_index(["year", "country"]).rename_axis(index={"country": config.additional_index})
test_arimax_pred_df = pd.read_csv(os.path.join(config.output_cleaned_hybrid, f'arimax_lstm/{variant_co2}/pca_arimax_pred_test.csv')).set_index(["year", "country"]).rename_axis(index={"country": config.additional_index})
train_arimax_pred_preprocessed, test_arimax_pred_preprocessed = data_preprocessor_lstm.preprocess_data(train_arimax_pred_df, test_arimax_pred_df)

# %%
train_lstm_df
# Out:
#                         country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1853 Stany Zjednoczone           34        0.016985  0.010509
# 1854 Stany Zjednoczone           34        0.017544  0.011437
# 1855 Stany Zjednoczone           34        0.018120  0.012690
# 1856 Stany Zjednoczone           34        0.018712  0.013083
# 1857 Stany Zjednoczone           34        0.019322  0.013194
# ...                             ...             ...       ...
# 1996 Szwecja                     35        0.005112  0.027868
# 1997 Szwecja                     35        0.005147  0.029056
# 1998 Szwecja                     35        0.005158  0.029609
# 1999 Szwecja                     35        0.005162  0.030501
# 2000 Szwecja                     35        0.005166  0.031881
#
#                         temperature_change_from_co2_t-2  cement_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone                         0.000000        0.000000
# 1854 Stany Zjednoczone                         0.006623        0.000000
# 1855 Stany Zjednoczone                         0.006623        0.000000
# 1856 Stany Zjednoczone                         0.013245        0.000000
# 1857 Stany Zjednoczone                         0.013245        0.000000
# ...                                                 ...             ...
# 1996 Szwecja                                   0.013245        0.002694
# 1997 Szwecja                                   0.013245        0.003148
# 1998 Szwecja                                   0.013245        0.002976
# 1999 Szwecja                                   0.013245        0.002684
# 2000 Szwecja                                   0.013245        0.002752
#
#                         coal_co2_t-2  flaring_co2_t-2  gas_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone      0.005568         0.000000     0.000000
# 1854 Stany Zjednoczone      0.006055         0.000000     0.000000
# 1855 Stany Zjednoczone      0.006817         0.000000     0.000000
# 1856 Stany Zjednoczone      0.007495         0.000000     0.000000
# 1857 Stany Zjednoczone      0.008625         0.000000     0.000000
# ...                              ...              ...          ...
# 1996 Szwecja                0.002540         0.003924     0.001725
# 1997 Szwecja                0.002537         0.004482     0.001754
# 1998 Szwecja                0.002800         0.004283     0.001892
# 1999 Szwecja                0.002437         0.004762     0.001918
# 2000 Szwecja                0.002511         0.004855     0.001897
#
#                         land_use_change_co2_t-2  oil_co2_t-2  ...  \
# year country_index                                            ...
# 1853 Stany Zjednoczone                 0.449621     0.000000  ...
# 1854 Stany Zjednoczone                 0.473915     0.000000  ...
# 1855 Stany Zjednoczone                 0.478863     0.000000  ...
# 1856 Stany Zjednoczone                 0.496390     0.000000  ...
# 1857 Stany Zjednoczone                 0.501668     0.000000  ...
# ...                                         ...          ...  ...
# 1996 Szwecja                           0.046782     0.017724  ...
# 1997 Szwecja                           0.048590     0.017440  ...
# 1998 Szwecja                           0.047746     0.018473  ...
# 1999 Szwecja                           0.048195     0.017144  ...
# 2000 Szwecja                           0.048532     0.017155  ...
#
#                         population_t-1   gdp_t-1  \
# year country_index
# 1853 Stany Zjednoczone        0.017393  0.010347
# 1854 Stany Zjednoczone        0.017965  0.011483
# 1855 Stany Zjednoczone        0.018554  0.011840
# 1856 Stany Zjednoczone        0.019160  0.011940
# 1857 Stany Zjednoczone        0.019785  0.012561
# ...                                ...       ...
# 1996 Szwecja                  0.005071  0.026320
# 1997 Szwecja                  0.005082  0.026822
# 1998 Szwecja                  0.005086  0.027630
# 1999 Szwecja                  0.005090  0.028881
# 2000 Szwecja                  0.005095  0.030321
#
#                         temperature_change_from_co2_t-1  cement_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone                         0.006536        0.000000
# 1854 Stany Zjednoczone                         0.006536        0.000000
# 1855 Stany Zjednoczone                         0.013072        0.000000
# 1856 Stany Zjednoczone                         0.013072        0.000000
# 1857 Stany Zjednoczone                         0.013072        0.000000
# ...                                                 ...             ...
# 1996 Szwecja                                   0.013072        0.002757
# 1997 Szwecja                                   0.013072        0.002606
# 1998 Szwecja                                   0.013072        0.002351
# 1999 Szwecja                                   0.013072        0.002410
# 2000 Szwecja                                   0.013072        0.002423
#
#                         coal_co2_t-1  flaring_co2_t-1  gas_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone      0.005462         0.000000     0.000000
# 1854 Stany Zjednoczone      0.006149         0.000000     0.000000
# 1855 Stany Zjednoczone      0.006760         0.000000     0.000000
# 1856 Stany Zjednoczone      0.007779         0.000000     0.000000
# 1857 Stany Zjednoczone      0.008162         0.000000     0.000000
# ...                              ...              ...          ...
# 1996 Szwecja                0.002288         0.004482     0.001754
# 1997 Szwecja                0.002525         0.004283     0.001892
# 1998 Szwecja                0.002198         0.004762     0.001918
# 1999 Szwecja                0.002264         0.004855     0.001897
# 2000 Szwecja                0.002048         0.004988     0.001847
#
#                         land_use_change_co2_t-1  oil_co2_t-1       co2
# year country_index
# 1853 Stany Zjednoczone                 0.351582     0.000000  0.142663
# 1854 Stany Zjednoczone                 0.355254     0.000000  0.148196
# 1855 Stany Zjednoczone                 0.368256     0.000000  0.150416
# 1856 Stany Zjednoczone                 0.372171     0.000000  0.154770
# 1857 Stany Zjednoczone                 0.382568     0.000000  0.156695
# ...                                         ...          ...       ...
# 1996 Szwecja                           0.036047     0.017440  0.021023
# 1997 Szwecja                           0.035421     0.018473  0.020478
# 1998 Szwecja                           0.035754     0.017144  0.020634
# 1999 Szwecja                           0.036005     0.017155  0.019864
# 2000 Szwecja                           0.035019     0.016472  0.020438
#
# [3153 rows x 21 columns]

# %%
train_arimax_pred_preprocessed
# Out:
#                         arimax_pred
# year country_index
# 1853 Stany Zjednoczone     0.166322
# 1854 Stany Zjednoczone     0.224336
# 1855 Stany Zjednoczone     0.226217
# 1856 Stany Zjednoczone     0.227094
# 1857 Stany Zjednoczone     0.228886
# ...                             ...
# 1996 Szwecja               0.176708
# 1997 Szwecja               0.176796
# 1998 Szwecja               0.176554
# 1999 Szwecja               0.176634
# 2000 Szwecja               0.176324
#
# [3153 rows x 1 columns]

# %%
#combine train df
train_hybrid_df = pd.merge(train_arimax_pred_preprocessed, train_lstm_df, left_index=True, right_index=True)
train_hybrid_df
# Out:
#                         arimax_pred  country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1853 Stany Zjednoczone     0.166322           34        0.016985  0.010509
# 1854 Stany Zjednoczone     0.224336           34        0.017544  0.011437
# 1855 Stany Zjednoczone     0.226217           34        0.018120  0.012690
# 1856 Stany Zjednoczone     0.227094           34        0.018712  0.013083
# 1857 Stany Zjednoczone     0.228886           34        0.019322  0.013194
# ...                             ...          ...             ...       ...
# 1996 Szwecja               0.176708           35        0.005112  0.027868
# 1997 Szwecja               0.176796           35        0.005147  0.029056
# 1998 Szwecja               0.176554           35        0.005158  0.029609
# 1999 Szwecja               0.176634           35        0.005162  0.030501
# 2000 Szwecja               0.176324           35        0.005166  0.031881
#
#                         temperature_change_from_co2_t-2  cement_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone                         0.000000        0.000000
# 1854 Stany Zjednoczone                         0.006623        0.000000
# 1855 Stany Zjednoczone                         0.006623        0.000000
# 1856 Stany Zjednoczone                         0.013245        0.000000
# 1857 Stany Zjednoczone                         0.013245        0.000000
# ...                                                 ...             ...
# 1996 Szwecja                                   0.013245        0.002694
# 1997 Szwecja                                   0.013245        0.003148
# 1998 Szwecja                                   0.013245        0.002976
# 1999 Szwecja                                   0.013245        0.002684
# 2000 Szwecja                                   0.013245        0.002752
#
#                         coal_co2_t-2  flaring_co2_t-2  gas_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone      0.005568         0.000000     0.000000
# 1854 Stany Zjednoczone      0.006055         0.000000     0.000000
# 1855 Stany Zjednoczone      0.006817         0.000000     0.000000
# 1856 Stany Zjednoczone      0.007495         0.000000     0.000000
# 1857 Stany Zjednoczone      0.008625         0.000000     0.000000
# ...                              ...              ...          ...
# 1996 Szwecja                0.002540         0.003924     0.001725
# 1997 Szwecja                0.002537         0.004482     0.001754
# 1998 Szwecja                0.002800         0.004283     0.001892
# 1999 Szwecja                0.002437         0.004762     0.001918
# 2000 Szwecja                0.002511         0.004855     0.001897
#
#                         land_use_change_co2_t-2  ...  population_t-1  \
# year country_index                               ...
# 1853 Stany Zjednoczone                 0.449621  ...        0.017393
# 1854 Stany Zjednoczone                 0.473915  ...        0.017965
# 1855 Stany Zjednoczone                 0.478863  ...        0.018554
# 1856 Stany Zjednoczone                 0.496390  ...        0.019160
# 1857 Stany Zjednoczone                 0.501668  ...        0.019785
# ...                                         ...  ...             ...
# 1996 Szwecja                           0.046782  ...        0.005071
# 1997 Szwecja                           0.048590  ...        0.005082
# 1998 Szwecja                           0.047746  ...        0.005086
# 1999 Szwecja                           0.048195  ...        0.005090
# 2000 Szwecja                           0.048532  ...        0.005095
#
#                          gdp_t-1  temperature_change_from_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone  0.010347                         0.006536
# 1854 Stany Zjednoczone  0.011483                         0.006536
# 1855 Stany Zjednoczone  0.011840                         0.013072
# 1856 Stany Zjednoczone  0.011940                         0.013072
# 1857 Stany Zjednoczone  0.012561                         0.013072
# ...                          ...                              ...
# 1996 Szwecja            0.026320                         0.013072
# 1997 Szwecja            0.026822                         0.013072
# 1998 Szwecja            0.027630                         0.013072
# 1999 Szwecja            0.028881                         0.013072
# 2000 Szwecja            0.030321                         0.013072
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.005462         0.000000
# 1854 Stany Zjednoczone        0.000000      0.006149         0.000000
# 1855 Stany Zjednoczone        0.000000      0.006760         0.000000
# 1856 Stany Zjednoczone        0.000000      0.007779         0.000000
# 1857 Stany Zjednoczone        0.000000      0.008162         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.002757      0.002288         0.004482
# 1997 Szwecja                  0.002606      0.002525         0.004283
# 1998 Szwecja                  0.002351      0.002198         0.004762
# 1999 Szwecja                  0.002410      0.002264         0.004855
# 2000 Szwecja                  0.002423      0.002048         0.004988
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone     0.000000                 0.351582     0.000000
# 1854 Stany Zjednoczone     0.000000                 0.355254     0.000000
# 1855 Stany Zjednoczone     0.000000                 0.368256     0.000000
# 1856 Stany Zjednoczone     0.000000                 0.372171     0.000000
# 1857 Stany Zjednoczone     0.000000                 0.382568     0.000000
# ...                             ...                      ...          ...
# 1996 Szwecja               0.001754                 0.036047     0.017440
# 1997 Szwecja               0.001892                 0.035421     0.018473
# 1998 Szwecja               0.001918                 0.035754     0.017144
# 1999 Szwecja               0.001897                 0.036005     0.017155
# 2000 Szwecja               0.001847                 0.035019     0.016472
#
#                              co2
# year country_index
# 1853 Stany Zjednoczone  0.142663
# 1854 Stany Zjednoczone  0.148196
# 1855 Stany Zjednoczone  0.150416
# 1856 Stany Zjednoczone  0.154770
# 1857 Stany Zjednoczone  0.156695
# ...                          ...
# 1996 Szwecja            0.021023
# 1997 Szwecja            0.020478
# 1998 Szwecja            0.020634
# 1999 Szwecja            0.019864
# 2000 Szwecja            0.020438
#
# [3153 rows x 22 columns]

# %%
#combine test df
test_hybrid_df = pd.merge(test_arimax_pred_preprocessed, test_lstm_df, left_index=True, right_index=True)
test_hybrid_df
# Out:
#                         arimax_pred  country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1989 Stany Zjednoczone     0.454856           34        0.186605  0.980192
# 1990 Stany Zjednoczone     0.458081           34        0.188312  1.021423
# 1991 Stany Zjednoczone     0.454799           34        0.190056  1.056778
# 1992 Stany Zjednoczone     0.450702           34        0.192119  1.075274
# 1993 Stany Zjednoczone     0.452820           34        0.194488  1.072287
# ...                             ...          ...             ...       ...
# 2019 Szwecja               0.177507           35        0.006089  0.052010
# 2020 Szwecja               0.177686           35        0.006179  0.053028
# 2021 Szwecja               0.177837           35        0.006258  0.054085
# 2022 Szwecja               0.178075           35        0.006315  0.052907
# 2023 Szwecja               0.178308           35        0.006363  0.055768
#
#                         temperature_change_from_co2_t-2  cement_co2_t-2  \
# year country_index
# 1989 Stany Zjednoczone                         1.013245        0.080107
# 1990 Stany Zjednoczone                         1.026490        0.080768
# 1991 Stany Zjednoczone                         1.039735        0.080807
# 1992 Stany Zjednoczone                         1.059603        0.081341
# 1993 Stany Zjednoczone                         1.072848        0.079524
# ...                                                 ...             ...
# 2019 Szwecja                                   0.019868        0.003605
# 2020 Szwecja                                   0.019868        0.003904
# 2021 Szwecja                                   0.019868        0.003296
# 2022 Szwecja                                   0.019868        0.003090
# 2023 Szwecja                                   0.019868        0.003058
#
#                         coal_co2_t-2  flaring_co2_t-2  gas_co2_t-2  \
# year country_index
# 1989 Stany Zjednoczone      0.386410         0.088209     0.785603
# 1990 Stany Zjednoczone      0.405226         0.101656     0.820841
# 1991 Stany Zjednoczone      0.409841         0.101017     0.874110
# 1992 Stany Zjednoczone      0.410125         0.616333     0.870813
# 1993 Stany Zjednoczone      0.406197         0.603152     0.886989
# ...                              ...              ...          ...
# 2019 Szwecja                0.001879         0.010654     0.001542
# 2020 Szwecja                0.001829         0.010973     0.001605
# 2021 Szwecja                0.001834         0.007129     0.001515
# 2022 Szwecja                0.001503         0.005919     0.001227
# 2023 Szwecja                0.001580         0.000120     0.001618
#
#                         land_use_change_co2_t-2  ...  population_t-1  \
# year country_index                               ...
# 1989 Stany Zjednoczone                 0.170489  ...        0.187127
# 1990 Stany Zjednoczone                 0.177344  ...        0.188861
# 1991 Stany Zjednoczone                 0.175863  ...        0.190911
# 1992 Stany Zjednoczone                 0.183932  ...        0.193265
# 1993 Stany Zjednoczone                 0.159215  ...        0.195648
# ...                                         ...  ...             ...
# 2019 Szwecja                           0.053336  ...        0.006096
# 2020 Szwecja                           0.053403  ...        0.006175
# 2021 Szwecja                           0.053656  ...        0.006232
# 2022 Szwecja                           0.053824  ...        0.006279
# 2023 Szwecja                           0.054231  ...        0.006333
#
#                          gdp_t-1  temperature_change_from_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone  0.925972                         1.013072
# 1990 Stany Zjednoczone  0.958024                         1.026144
# 1991 Stany Zjednoczone  0.974791                         1.045752
# 1992 Stany Zjednoczone  0.972084                         1.058824
# 1993 Stany Zjednoczone  1.006652                         1.071895
# ...                          ...                              ...
# 2019 Szwecja            0.048052                         0.019608
# 2020 Szwecja            0.049011                         0.019608
# 2021 Szwecja            0.047943                         0.019608
# 2022 Szwecja            0.050536                         0.019608
# 2023 Szwecja            0.051877                         0.019608
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone        0.070727      0.365490         0.101656
# 1990 Stany Zjednoczone        0.070761      0.369653         0.101017
# 1991 Stany Zjednoczone        0.071229      0.369909         0.616333
# 1992 Stany Zjednoczone        0.069638      0.366365         0.603152
# 1993 Stany Zjednoczone        0.070185      0.370468         0.598723
# ...                                ...           ...              ...
# 2019 Szwecja                  0.003419      0.001650         0.010973
# 2020 Szwecja                  0.002887      0.001654         0.007129
# 2021 Szwecja                  0.002706      0.001355         0.005919
# 2022 Szwecja                  0.002678      0.001425         0.000120
# 2023 Szwecja                  0.002678      0.001409         0.000160
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone     0.820841                 0.131566     0.887696
# 1990 Stany Zjednoczone     0.874110                 0.130467     0.887150
# 1991 Stany Zjednoczone     0.870813                 0.136453     0.862972
# 1992 Stany Zjednoczone     0.886989                 0.118116     0.840136
# 1993 Stany Zjednoczone     0.919292                 0.101080     0.861291
# ...                             ...                      ...          ...
# 2019 Szwecja               0.001605                 0.039618     0.011526
# 2020 Szwecja               0.001515                 0.039806     0.011298
# 2021 Szwecja               0.001227                 0.039930     0.010443
# 2022 Szwecja               0.001618                 0.040232     0.011072
# 2023 Szwecja               0.001319                 0.040374     0.010298
#
#                              co2
# year country_index
# 1989 Stany Zjednoczone  0.744042
# 1990 Stany Zjednoczone  0.744836
# 1991 Stany Zjednoczone  0.729761
# 1992 Stany Zjednoczone  0.738090
# 1993 Stany Zjednoczone  0.749304
# ...                          ...
# 2019 Szwecja            0.019703
# 2020 Szwecja            0.019193
# 2021 Szwecja            0.019574
# 2022 Szwecja            0.019473
# 2023 Szwecja            0.019380
#
# [816 rows x 22 columns]

# %% [markdown]
# ## Reshape the data

# %%
data_resherper = DataReshaperLSTM()
x_train, x_test, y_train, y_test = data_resherper.reshape_data(train_hybrid_df, test_hybrid_df)

# %% [markdown]
# ## Build the model

# %%
input_shape = (x_train.shape[1], x_train.shape[2])
output_units = 1

model = Sequential([
    LSTM(96, input_shape=input_shape, return_sequences = True),
    Dropout(0.2),
    LSTM(80),
    Dropout(0.2),
    Dense(output_units, activation='relu')
])

model.compile(optimizer="adam", loss="mean_squared_error")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 96)             45312
#
#  dropout (Dropout)           (None, 1, 96)             0
#
#  lstm_1 (LSTM)               (None, 80)                56640
#
#  dropout_1 (Dropout)         (None, 80)                0
#
#  dense (Dense)               (None, 1)                 81
#
# =================================================================
# Total params: 102,033
# Trainable params: 102,033
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
early_stopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=config.epochs, batch_size=config.batch_size, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 99/99 [==============================] - 2s 5ms/step - loss: 0.0076
# Epoch 2/100
# 99/99 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 3/100
# 99/99 [==============================] - 0s 4ms/step - loss: 6.7802e-04
# Epoch 4/100
# 99/99 [==============================] - 0s 3ms/step - loss: 6.0598e-04
# Epoch 5/100
# 99/99 [==============================] - 0s 2ms/step - loss: 6.2824e-04
# Epoch 6/100
# 99/99 [==============================] - 0s 2ms/step - loss: 6.0418e-04
# Epoch 7/100
# 99/99 [==============================] - 0s 3ms/step - loss: 4.5828e-04
# Epoch 8/100
# 99/99 [==============================] - 0s 3ms/step - loss: 4.1529e-04
# Epoch 9/100
# 99/99 [==============================] - 0s 3ms/step - loss: 4.8389e-04
# Epoch 10/100
# 99/99 [==============================] - 0s 2ms/step - loss: 3.7965e-04
# Epoch 11/100
# 99/99 [==============================] - 0s 2ms/step - loss: 4.1231e-04
# Epoch 12/100
# 99/99 [==============================] - 0s 2ms/step - loss: 3.9601e-04
# Epoch 13/100
# 99/99 [==============================] - 0s 3ms/step - loss: 3.7024e-04
# Epoch 14/100
# 99/99 [==============================] - 0s 2ms/step - loss: 3.2461e-04
# Epoch 15/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.5383e-04
# Epoch 16/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.6142e-04
# Epoch 17/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.6177e-04
# Epoch 18/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.2578e-04
# Epoch 19/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.5849e-04
# Epoch 20/100
# 99/99 [==============================] - 0s 2ms/step - loss: 3.2856e-04
# Epoch 21/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.4707e-04
# Epoch 22/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.4134e-04
# Epoch 23/100
# 99/99 [==============================] - 0s 2ms/step - loss: 3.0481e-04
# Epoch 24/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.6502e-04
# Epoch 25/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.9166e-04
# Epoch 26/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.6736e-04
# Epoch 27/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.5295e-04
# Epoch 28/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.4921e-04
# Epoch 29/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.5365e-04
# Epoch 30/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.6905e-04
# Epoch 31/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.6204e-04
# Epoch 32/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.8828e-04
# Epoch 33/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.8332e-04
# Epoch 34/100
# 99/99 [==============================] - 0s 2ms/step - loss: 2.3591e-04
# Epoch 35/100
# 99/99 [==============================] - 0s 2ms/step - loss: 3.1061e-04
# Epoch 36/100
# 99/99 [==============================] - 0s 1ms/step - loss: 3.3131e-04
# Epoch 37/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.5977e-04
# Epoch 38/100
# 99/99 [==============================] - 0s 2ms/step - loss: 2.4827e-04
# Epoch 39/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.7224e-04
# Epoch 40/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.6728e-04
# Epoch 41/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.8375e-04
# Epoch 42/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.7649e-04
# Epoch 43/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.6634e-04
# Epoch 44/100
# 99/99 [==============================] - 0s 1ms/step - loss: 2.7300e-04

# %%
# Save the model
model.save(os.path.join(config.models_folder, f'{variant_co2}_pca_arimax_lstm_model.h5'))

# Evaluate the model on the test set
loss = model.evaluate(x_test, y_test, verbose = 0)

# %% [markdown]
# ## Predictions

# %%
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)

inverted_data_predicted_train_y = data_preprocessor_lstm.inverse_transform_data(train_predictions, train_predictions.shape[0], train_hybrid_df.shape[1]-2)
inverted_data_train_y = data_preprocessor_lstm.inverse_transform_data(y_train, train_predictions.shape[0], train_hybrid_df.shape[1]-2)

inverted_data_predicted_test_y = data_preprocessor_lstm.inverse_transform_data(test_predictions, test_predictions.shape[0], test_hybrid_df.shape[1]-2)
inverted_data_test_y = data_preprocessor_lstm.inverse_transform_data(y_test, test_predictions.shape[0], test_hybrid_df.shape[1]-2)
# Out:
# 99/99 [==============================] - 0s 664us/step
# 26/26 [==============================] - 0s 519us/step

# %%
train_df_reset = train_hybrid_df.reset_index()
test_df_reset = test_hybrid_df.reset_index()

co2_predicted_train = inverted_data_predicted_train_y[:, -1]
co2_actual_train = inverted_data_train_y[:, -1]
co2_predicted_test = inverted_data_predicted_test_y[:, -1]
co2_actual_test = inverted_data_test_y[:, -1]

# Create DataFrames for train and test
train_results = pd.DataFrame({
    "country": train_df_reset["country_index"].values,
    "year": train_df_reset["year"].values,
    "co2_predicted": co2_predicted_train,
    "co2_actual": co2_actual_train
})

test_results = pd.DataFrame({
    "country": test_df_reset["country_index"].values,
    "year": test_df_reset["year"].values,
    "co2_predicted": co2_predicted_test,
    "co2_actual": co2_actual_test
})


train_results.to_csv(os.path.join(config.predictions_hybrid_arimax_lstm, f'arimax_lstm_{variant_co2}_train.csv'))
test_results.to_csv(os.path.join(config.predictions_hybrid_arimax_lstm, f'arimax_lstm_{variant_co2}_test.csv'))

# %%
current_model = "arimax_pca_lstm"

global_csv_path = os.path.join(config.predictions, f'combined_results_{variant_co2}.csv')
global_results = GlobalResults(global_csv_path, keys=["country", "year", "set"])

train = train_results.copy()
test = test_results.copy()

if "year" not in train.columns:
    train = train.reset_index()
if "year" not in test.columns:
    test = test.reset_index()

train["set"] = "train"
test["set"] = "test"

train = train.rename(columns={
    "co2_predicted": f"co2_predicted_{current_model}",
    "co2_actual": f"co2_actual_{current_model}"
})
test = test.rename(columns={
    "co2_predicted": f"co2_predicted_{current_model}",
    "co2_actual": f"co2_actual_{current_model}"
})

new_results_df = pd.concat([train, test], axis=0)
new_results_df = new_results_df.sort_values(by=["year", "country", "set"])

global_results.append_results(new_results_df)

# %% [markdown]
# ## Charts

# %%
charts = ModelCharts(train_results, test_results)

#Line plot
charts.generate_line_plot(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm)
charts.generate_line_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='train')
charts.generate_line_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='test')

#Scatter plot
charts.generate_scatter_plot(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm)
charts.generate_scatter_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='train')
charts.generate_scatter_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='test')

# %% [markdown]
# ## Metrics

# %%
evaluator = PredictionEvaluator()
evaluator.evaluate(train_results, test_results, actual_col='co2_actual', predicted_col='co2_predicted', variant = f'arimax_lstm_{variant_co2}_pca', model_output_file=config.metrics_hybrid)
