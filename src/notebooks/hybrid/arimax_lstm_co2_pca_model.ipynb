# %%
import os
import pickle

import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

from src.data_preparation.data_preprocessing import DataReshaperLSTM
from src.visualization.charts import ModelCharts
from src.visualization.metrics import PredictionEvaluator
from src.config import Config

# %% [markdown]
# ## Load the data

# %%
config = Config()
variant_co2 = 'co2'

#lstm
train_lstm_df = pd.read_csv(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/train.csv')).set_index(["year", config.additional_index]).drop(columns=['country_order'])
test_lstm_df = pd.read_csv(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/test.csv')).set_index(["year", config.additional_index]).drop(columns=['country_order'])

with open(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/data_preprocessor_lstm.pkl'), 'rb') as f:
    data_preprocessor_lstm = pickle.load(f)

#residual arimax
train_arimax_residuals_df = pd.read_csv(os.path.join(config.output_cleaned_hybrid, f'arimax_lstm/{variant_co2}/pca_residuals_train.csv')).set_index(["year", "country"]).rename_axis(index={"country": config.additional_index})
test_arimax_residuals_df = pd.read_csv(os.path.join(config.output_cleaned_hybrid, f'arimax_lstm/{variant_co2}/pca_residuals_test.csv')).set_index(["year", "country"]).rename_axis(index={"country": config.additional_index})
train_arimax_residuals_preprocessed, test_arimax_residuals_preprocessed = data_preprocessor_lstm.preprocess_data(train_arimax_residuals_df, test_arimax_residuals_df)

# %%
train_lstm_df
# Out:
#                         country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1853 Stany Zjednoczone           34        0.016985  0.010509
# 1854 Stany Zjednoczone           34        0.017544  0.011437
# 1855 Stany Zjednoczone           34        0.018120  0.012690
# 1856 Stany Zjednoczone           34        0.018712  0.013083
# 1857 Stany Zjednoczone           34        0.019322  0.013194
# ...                             ...             ...       ...
# 1996 Szwecja                     35        0.005112  0.027868
# 1997 Szwecja                     35        0.005147  0.029056
# 1998 Szwecja                     35        0.005158  0.029609
# 1999 Szwecja                     35        0.005162  0.030501
# 2000 Szwecja                     35        0.005166  0.031881
#
#                         temperature_change_from_co2_t-2  total_ghg_t-2  \
# year country_index
# 1853 Stany Zjednoczone                         0.000000       0.119705
# 1854 Stany Zjednoczone                         0.006623       0.125772
# 1855 Stany Zjednoczone                         0.006623       0.126702
# 1856 Stany Zjednoczone                         0.013245       0.131413
# 1857 Stany Zjednoczone                         0.013245       0.133173
# ...                                                 ...            ...
# 1996 Szwecja                                   0.013245       0.008810
# 1997 Szwecja                                   0.013245       0.009214
# 1998 Szwecja                                   0.013245       0.009687
# 1999 Szwecja                                   0.013245       0.009227
# 2000 Szwecja                                   0.013245       0.009360
#
#                         cement_co2_t-2  coal_co2_t-2  flaring_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.005568         0.000000
# 1854 Stany Zjednoczone        0.000000      0.006055         0.000000
# 1855 Stany Zjednoczone        0.000000      0.006817         0.000000
# 1856 Stany Zjednoczone        0.000000      0.007495         0.000000
# 1857 Stany Zjednoczone        0.000000      0.008625         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.002694      0.002540         0.003924
# 1997 Szwecja                  0.003148      0.002537         0.004482
# 1998 Szwecja                  0.002976      0.002800         0.004283
# 1999 Szwecja                  0.002684      0.002437         0.004762
# 2000 Szwecja                  0.002752      0.002511         0.004855
#
#                         gas_co2_t-2  land_use_change_co2_t-2  ...   gdp_t-1  \
# year country_index                                            ...
# 1853 Stany Zjednoczone     0.000000                 0.449621  ...  0.010347
# 1854 Stany Zjednoczone     0.000000                 0.473915  ...  0.011483
# 1855 Stany Zjednoczone     0.000000                 0.478863  ...  0.011840
# 1856 Stany Zjednoczone     0.000000                 0.496390  ...  0.011940
# 1857 Stany Zjednoczone     0.000000                 0.501668  ...  0.012561
# ...                             ...                      ...  ...       ...
# 1996 Szwecja               0.001725                 0.046782  ...  0.026320
# 1997 Szwecja               0.001754                 0.048590  ...  0.026822
# 1998 Szwecja               0.001892                 0.047746  ...  0.027630
# 1999 Szwecja               0.001918                 0.048195  ...  0.028881
# 2000 Szwecja               0.001897                 0.048532  ...  0.030321
#
#                         temperature_change_from_co2_t-1  total_ghg_t-1  \
# year country_index
# 1853 Stany Zjednoczone                         0.006536       0.115255
# 1854 Stany Zjednoczone                         0.006536       0.116109
# 1855 Stany Zjednoczone                         0.013072       0.120435
# 1856 Stany Zjednoczone                         0.013072       0.122052
# 1857 Stany Zjednoczone                         0.013072       0.125706
# ...                                                 ...            ...
# 1996 Szwecja                                   0.013072       0.008216
# 1997 Szwecja                                   0.013072       0.008650
# 1998 Szwecja                                   0.013072       0.008228
# 1999 Szwecja                                   0.013072       0.008350
# 2000 Szwecja                                   0.013072       0.007897
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.005462         0.000000
# 1854 Stany Zjednoczone        0.000000      0.006149         0.000000
# 1855 Stany Zjednoczone        0.000000      0.006760         0.000000
# 1856 Stany Zjednoczone        0.000000      0.007779         0.000000
# 1857 Stany Zjednoczone        0.000000      0.008162         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.002757      0.002288         0.004482
# 1997 Szwecja                  0.002606      0.002525         0.004283
# 1998 Szwecja                  0.002351      0.002198         0.004762
# 1999 Szwecja                  0.002410      0.002264         0.004855
# 2000 Szwecja                  0.002423      0.002048         0.004988
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone     0.000000                 0.351582     0.000000
# 1854 Stany Zjednoczone     0.000000                 0.355254     0.000000
# 1855 Stany Zjednoczone     0.000000                 0.368256     0.000000
# 1856 Stany Zjednoczone     0.000000                 0.372171     0.000000
# 1857 Stany Zjednoczone     0.000000                 0.382568     0.000000
# ...                             ...                      ...          ...
# 1996 Szwecja               0.001754                 0.036047     0.017440
# 1997 Szwecja               0.001892                 0.035421     0.018473
# 1998 Szwecja               0.001918                 0.035754     0.017144
# 1999 Szwecja               0.001897                 0.036005     0.017155
# 2000 Szwecja               0.001847                 0.035019     0.016472
#
#                              co2
# year country_index
# 1853 Stany Zjednoczone  0.142663
# 1854 Stany Zjednoczone  0.148196
# 1855 Stany Zjednoczone  0.150416
# 1856 Stany Zjednoczone  0.154770
# 1857 Stany Zjednoczone  0.156695
# ...                          ...
# 1996 Szwecja            0.021023
# 1997 Szwecja            0.020478
# 1998 Szwecja            0.020634
# 1999 Szwecja            0.019864
# 2000 Szwecja            0.020438
#
# [3153 rows x 23 columns]

# %%
train_arimax_residuals_preprocessed
# Out:
#                         residual
# year country_index
# 1853 Stany Zjednoczone  0.141126
# 1854 Stany Zjednoczone  0.088656
# 1855 Stany Zjednoczone  0.087788
# 1856 Stany Zjednoczone  0.088473
# 1857 Stany Zjednoczone  0.087396
# ...                          ...
# 1996 Szwecja            0.087386
# 1997 Szwecja            0.087139
# 1998 Szwecja            0.087399
# 1999 Szwecja            0.087079
# 2000 Szwecja            0.087527
#
# [3153 rows x 1 columns]

# %%
#combine train df
train_hybrid_df = pd.merge(train_arimax_residuals_preprocessed, train_lstm_df, left_index=True, right_index=True)
train_hybrid_df
# Out:
#                         residual  country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1853 Stany Zjednoczone  0.141126           34        0.016985  0.010509
# 1854 Stany Zjednoczone  0.088656           34        0.017544  0.011437
# 1855 Stany Zjednoczone  0.087788           34        0.018120  0.012690
# 1856 Stany Zjednoczone  0.088473           34        0.018712  0.013083
# 1857 Stany Zjednoczone  0.087396           34        0.019322  0.013194
# ...                          ...          ...             ...       ...
# 1996 Szwecja            0.087386           35        0.005112  0.027868
# 1997 Szwecja            0.087139           35        0.005147  0.029056
# 1998 Szwecja            0.087399           35        0.005158  0.029609
# 1999 Szwecja            0.087079           35        0.005162  0.030501
# 2000 Szwecja            0.087527           35        0.005166  0.031881
#
#                         temperature_change_from_co2_t-2  total_ghg_t-2  \
# year country_index
# 1853 Stany Zjednoczone                         0.000000       0.119705
# 1854 Stany Zjednoczone                         0.006623       0.125772
# 1855 Stany Zjednoczone                         0.006623       0.126702
# 1856 Stany Zjednoczone                         0.013245       0.131413
# 1857 Stany Zjednoczone                         0.013245       0.133173
# ...                                                 ...            ...
# 1996 Szwecja                                   0.013245       0.008810
# 1997 Szwecja                                   0.013245       0.009214
# 1998 Szwecja                                   0.013245       0.009687
# 1999 Szwecja                                   0.013245       0.009227
# 2000 Szwecja                                   0.013245       0.009360
#
#                         cement_co2_t-2  coal_co2_t-2  flaring_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.005568         0.000000
# 1854 Stany Zjednoczone        0.000000      0.006055         0.000000
# 1855 Stany Zjednoczone        0.000000      0.006817         0.000000
# 1856 Stany Zjednoczone        0.000000      0.007495         0.000000
# 1857 Stany Zjednoczone        0.000000      0.008625         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.002694      0.002540         0.003924
# 1997 Szwecja                  0.003148      0.002537         0.004482
# 1998 Szwecja                  0.002976      0.002800         0.004283
# 1999 Szwecja                  0.002684      0.002437         0.004762
# 2000 Szwecja                  0.002752      0.002511         0.004855
#
#                         gas_co2_t-2  ...   gdp_t-1  \
# year country_index                   ...
# 1853 Stany Zjednoczone     0.000000  ...  0.010347
# 1854 Stany Zjednoczone     0.000000  ...  0.011483
# 1855 Stany Zjednoczone     0.000000  ...  0.011840
# 1856 Stany Zjednoczone     0.000000  ...  0.011940
# 1857 Stany Zjednoczone     0.000000  ...  0.012561
# ...                             ...  ...       ...
# 1996 Szwecja               0.001725  ...  0.026320
# 1997 Szwecja               0.001754  ...  0.026822
# 1998 Szwecja               0.001892  ...  0.027630
# 1999 Szwecja               0.001918  ...  0.028881
# 2000 Szwecja               0.001897  ...  0.030321
#
#                         temperature_change_from_co2_t-1  total_ghg_t-1  \
# year country_index
# 1853 Stany Zjednoczone                         0.006536       0.115255
# 1854 Stany Zjednoczone                         0.006536       0.116109
# 1855 Stany Zjednoczone                         0.013072       0.120435
# 1856 Stany Zjednoczone                         0.013072       0.122052
# 1857 Stany Zjednoczone                         0.013072       0.125706
# ...                                                 ...            ...
# 1996 Szwecja                                   0.013072       0.008216
# 1997 Szwecja                                   0.013072       0.008650
# 1998 Szwecja                                   0.013072       0.008228
# 1999 Szwecja                                   0.013072       0.008350
# 2000 Szwecja                                   0.013072       0.007897
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.005462         0.000000
# 1854 Stany Zjednoczone        0.000000      0.006149         0.000000
# 1855 Stany Zjednoczone        0.000000      0.006760         0.000000
# 1856 Stany Zjednoczone        0.000000      0.007779         0.000000
# 1857 Stany Zjednoczone        0.000000      0.008162         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.002757      0.002288         0.004482
# 1997 Szwecja                  0.002606      0.002525         0.004283
# 1998 Szwecja                  0.002351      0.002198         0.004762
# 1999 Szwecja                  0.002410      0.002264         0.004855
# 2000 Szwecja                  0.002423      0.002048         0.004988
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone     0.000000                 0.351582     0.000000
# 1854 Stany Zjednoczone     0.000000                 0.355254     0.000000
# 1855 Stany Zjednoczone     0.000000                 0.368256     0.000000
# 1856 Stany Zjednoczone     0.000000                 0.372171     0.000000
# 1857 Stany Zjednoczone     0.000000                 0.382568     0.000000
# ...                             ...                      ...          ...
# 1996 Szwecja               0.001754                 0.036047     0.017440
# 1997 Szwecja               0.001892                 0.035421     0.018473
# 1998 Szwecja               0.001918                 0.035754     0.017144
# 1999 Szwecja               0.001897                 0.036005     0.017155
# 2000 Szwecja               0.001847                 0.035019     0.016472
#
#                              co2
# year country_index
# 1853 Stany Zjednoczone  0.142663
# 1854 Stany Zjednoczone  0.148196
# 1855 Stany Zjednoczone  0.150416
# 1856 Stany Zjednoczone  0.154770
# 1857 Stany Zjednoczone  0.156695
# ...                          ...
# 1996 Szwecja            0.021023
# 1997 Szwecja            0.020478
# 1998 Szwecja            0.020634
# 1999 Szwecja            0.019864
# 2000 Szwecja            0.020438
#
# [3153 rows x 24 columns]

# %%
#combine test df
test_hybrid_df = pd.merge(test_arimax_residuals_preprocessed, test_lstm_df, left_index=True, right_index=True)
test_hybrid_df
# Out:
#                         residual  country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1989 Stany Zjednoczone  0.088356           34        0.186605  0.980192
# 1990 Stany Zjednoczone  0.085855           34        0.188312  1.021423
# 1991 Stany Zjednoczone  0.084109           34        0.190056  1.056778
# 1992 Stany Zjednoczone  0.090313           34        0.192119  1.075274
# 1993 Stany Zjednoczone  0.091814           34        0.194488  1.072287
# ...                          ...          ...             ...       ...
# 2019 Szwecja            0.086283           35        0.006089  0.052010
# 2020 Szwecja            0.085974           35        0.006179  0.053028
# 2021 Szwecja            0.085986           35        0.006258  0.054085
# 2022 Szwecja            0.085768           35        0.006315  0.052907
# 2023 Szwecja            0.085541           35        0.006363  0.055768
#
#                         temperature_change_from_co2_t-2  total_ghg_t-2  \
# year country_index
# 1989 Stany Zjednoczone                         1.013245       0.770779
# 1990 Stany Zjednoczone                         1.026490       0.801646
# 1991 Stany Zjednoczone                         1.039735       0.812559
# 1992 Stany Zjednoczone                         1.059603       0.809374
# 1993 Stany Zjednoczone                         1.072848       0.800357
# ...                                                 ...            ...
# 2019 Szwecja                                   0.019868       0.009155
# 2020 Szwecja                                   0.019868       0.008925
# 2021 Szwecja                                   0.019868       0.008773
# 2022 Szwecja                                   0.019868       0.008262
# 2023 Szwecja                                   0.019868       0.008657
#
#                         cement_co2_t-2  coal_co2_t-2  flaring_co2_t-2  \
# year country_index
# 1989 Stany Zjednoczone        0.080107      0.386410         0.088209
# 1990 Stany Zjednoczone        0.080768      0.405226         0.101656
# 1991 Stany Zjednoczone        0.080807      0.409841         0.101017
# 1992 Stany Zjednoczone        0.081341      0.410125         0.616333
# 1993 Stany Zjednoczone        0.079524      0.406197         0.603152
# ...                                ...           ...              ...
# 2019 Szwecja                  0.003605      0.001879         0.010654
# 2020 Szwecja                  0.003904      0.001829         0.010973
# 2021 Szwecja                  0.003296      0.001834         0.007129
# 2022 Szwecja                  0.003090      0.001503         0.005919
# 2023 Szwecja                  0.003058      0.001580         0.000120
#
#                         gas_co2_t-2  ...   gdp_t-1  \
# year country_index                   ...
# 1989 Stany Zjednoczone     0.785603  ...  0.925972
# 1990 Stany Zjednoczone     0.820841  ...  0.958024
# 1991 Stany Zjednoczone     0.874110  ...  0.974791
# 1992 Stany Zjednoczone     0.870813  ...  0.972084
# 1993 Stany Zjednoczone     0.886989  ...  1.006652
# ...                             ...  ...       ...
# 2019 Szwecja               0.001542  ...  0.048052
# 2020 Szwecja               0.001605  ...  0.049011
# 2021 Szwecja               0.001515  ...  0.047943
# 2022 Szwecja               0.001227  ...  0.050536
# 2023 Szwecja               0.001618  ...  0.051877
#
#                         temperature_change_from_co2_t-1  total_ghg_t-1  \
# year country_index
# 1989 Stany Zjednoczone                         1.013072       0.735932
# 1990 Stany Zjednoczone                         1.026144       0.745954
# 1991 Stany Zjednoczone                         1.045752       0.743029
# 1992 Stany Zjednoczone                         1.058824       0.734748
# 1993 Stany Zjednoczone                         1.071895       0.747962
# ...                                                 ...            ...
# 2019 Szwecja                                   0.019608       0.007950
# 2020 Szwecja                                   0.019608       0.007811
# 2021 Szwecja                                   0.019608       0.007342
# 2022 Szwecja                                   0.019608       0.007704
# 2023 Szwecja                                   0.019608       0.007451
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone        0.070727      0.365490         0.101656
# 1990 Stany Zjednoczone        0.070761      0.369653         0.101017
# 1991 Stany Zjednoczone        0.071229      0.369909         0.616333
# 1992 Stany Zjednoczone        0.069638      0.366365         0.603152
# 1993 Stany Zjednoczone        0.070185      0.370468         0.598723
# ...                                ...           ...              ...
# 2019 Szwecja                  0.003419      0.001650         0.010973
# 2020 Szwecja                  0.002887      0.001654         0.007129
# 2021 Szwecja                  0.002706      0.001355         0.005919
# 2022 Szwecja                  0.002678      0.001425         0.000120
# 2023 Szwecja                  0.002678      0.001409         0.000160
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone     0.820841                 0.131566     0.887696
# 1990 Stany Zjednoczone     0.874110                 0.130467     0.887150
# 1991 Stany Zjednoczone     0.870813                 0.136453     0.862972
# 1992 Stany Zjednoczone     0.886989                 0.118116     0.840136
# 1993 Stany Zjednoczone     0.919292                 0.101080     0.861291
# ...                             ...                      ...          ...
# 2019 Szwecja               0.001605                 0.039618     0.011526
# 2020 Szwecja               0.001515                 0.039806     0.011298
# 2021 Szwecja               0.001227                 0.039930     0.010443
# 2022 Szwecja               0.001618                 0.040232     0.011072
# 2023 Szwecja               0.001319                 0.040374     0.010298
#
#                              co2
# year country_index
# 1989 Stany Zjednoczone  0.744042
# 1990 Stany Zjednoczone  0.744836
# 1991 Stany Zjednoczone  0.729761
# 1992 Stany Zjednoczone  0.738090
# 1993 Stany Zjednoczone  0.749304
# ...                          ...
# 2019 Szwecja            0.019703
# 2020 Szwecja            0.019193
# 2021 Szwecja            0.019574
# 2022 Szwecja            0.019473
# 2023 Szwecja            0.019380
#
# [816 rows x 24 columns]

# %% [markdown]
# ## Reshape the data

# %%
data_resherper = DataReshaperLSTM()
x_train, x_test, y_train, y_test = data_resherper.reshape_data(train_hybrid_df, test_hybrid_df)

# %% [markdown]
# ## Build the model

# %%
input_shape = (x_train.shape[1], x_train.shape[2])
output_units = 1

model = Sequential([
    LSTM(50, input_shape=input_shape, return_sequences = True),
    Dropout(0.2),
    LSTM(50),
    Dropout(0.2),
    Dense(output_units, activation='relu')
])

model.compile(optimizer="adam", loss="mean_squared_error")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 50)             14800
#
#  dropout (Dropout)           (None, 1, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 35,051
# Trainable params: 35,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(x_train, y_train, epochs=config.epochs, batch_size=config.batch_size)
# Out:
# Epoch 1/15
# 3153/3153 [==============================] - 3s 713us/step - loss: 0.0156
# Epoch 2/15
# 3153/3153 [==============================] - 2s 721us/step - loss: 0.0157
# Epoch 3/15
# 3153/3153 [==============================] - 2s 679us/step - loss: 0.0157
# Epoch 4/15
# 3153/3153 [==============================] - 2s 686us/step - loss: 0.0157
# Epoch 5/15
# 3153/3153 [==============================] - 2s 763us/step - loss: 0.0157
# Epoch 6/15
# 3153/3153 [==============================] - 2s 683us/step - loss: 0.0157
# Epoch 7/15
# 3153/3153 [==============================] - 2s 667us/step - loss: 0.0157
# Epoch 8/15
# 3153/3153 [==============================] - 2s 672us/step - loss: 0.0157
# Epoch 9/15
# 3153/3153 [==============================] - 2s 716us/step - loss: 0.0157
# Epoch 10/15
# 3153/3153 [==============================] - 2s 672us/step - loss: 0.0157
# Epoch 11/15
# 3153/3153 [==============================] - 2s 782us/step - loss: 0.0157
# Epoch 12/15
# 3153/3153 [==============================] - 2s 702us/step - loss: 0.0157
# Epoch 13/15
# 3153/3153 [==============================] - 2s 703us/step - loss: 0.0157
# Epoch 14/15
# 3153/3153 [==============================] - 2s 687us/step - loss: 0.0157
# Epoch 15/15
# 3153/3153 [==============================] - 2s 664us/step - loss: 0.0157

# %%
# Save the model
model.save(os.path.join(config.models_folder, f'{variant_co2}_pca_arimax_lstm_model.h5'))

# Evaluate the model on the test set
loss = model.evaluate(x_test, y_test, verbose = 0)

# %% [markdown]
# ## Predictions

# %%
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)

inverted_data_predicted_train_y = data_preprocessor_lstm.inverse_transform_data(train_predictions, train_predictions.shape[0], train_hybrid_df.shape[1]-2)
inverted_data_train_y = data_preprocessor_lstm.inverse_transform_data(y_train, train_predictions.shape[0], train_hybrid_df.shape[1]-2)

inverted_data_predicted_test_y = data_preprocessor_lstm.inverse_transform_data(test_predictions, test_predictions.shape[0], test_hybrid_df.shape[1]-2)
inverted_data_test_y = data_preprocessor_lstm.inverse_transform_data(y_test, test_predictions.shape[0], test_hybrid_df.shape[1]-2)
# Out:
# 99/99 [==============================] - 0s 441us/step
# 26/26 [==============================] - 0s 433us/step

# %%
train_df_reset = train_hybrid_df.reset_index()
test_df_reset = test_hybrid_df.reset_index()

co2_predicted_train = inverted_data_predicted_train_y[:, -1]
co2_actual_train = inverted_data_train_y[:, -1]
co2_predicted_test = inverted_data_predicted_test_y[:, -1]
co2_actual_test = inverted_data_test_y[:, -1]

# Create DataFrames for train and test
train_results = pd.DataFrame({
    "country": train_df_reset["country_index"].values,
    "year": train_df_reset["year"].values,
    "co2_predicted": co2_predicted_train,
    "co2_actual": co2_actual_train
})

test_results = pd.DataFrame({
    "country": test_df_reset["country_index"].values,
    "year": test_df_reset["year"].values,
    "co2_predicted": co2_predicted_test,
    "co2_actual": co2_actual_test
})


train_results.to_csv(os.path.join(config.predictions_hybrid_arimax_lstm, f'arimax_lstm_{variant_co2}_train.csv'))
test_results.to_csv(os.path.join(config.predictions_hybrid_arimax_lstm, f'arimax_lstm_{variant_co2}_test.csv'))

# %% [markdown]
# ## Charts

# %%
charts = ModelCharts(train_results, test_results)

#Line plot
charts.generate_line_plot(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm)
charts.generate_line_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='train')
charts.generate_line_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='test')

#Scatter plot
charts.generate_scatter_plot(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm)
charts.generate_scatter_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='train')
charts.generate_scatter_plot_one_dataset(variant = f'{variant_co2}_pca', model_output_file=config.predictions_hybrid_arimax_lstm, dataset_type='test')

# %% [markdown]
# ## Metrics

# %%
evaluator = PredictionEvaluator()
evaluator.evaluate(train_results, test_results, actual_col='co2_actual', predicted_col='co2_predicted', variant = f'arimax_lstm_{variant_co2}_pca', model_output_file=config.metrics_hybrid)
