# %%
import os
import pickle

import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

from src.data_preparation.data_preprocessing import DataReshaperLSTM
from src.visualization.charts import ModelCharts
from src.visualization.metrics import PredictionEvaluator
from src.config import Config

# %% [markdown]
# ## Load the data

# %%
config = Config()
variant_co2 = 'co2_per_capita'

#lstm
train_lstm_df = pd.read_csv(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/train.csv')).set_index(["year", config.additional_index]).drop(columns=['country_order'])
test_lstm_df = pd.read_csv(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/test.csv')).set_index(["year", config.additional_index]).drop(columns=['country_order'])

with open(os.path.join(config.output_cleaned_lstm, f'{variant_co2}/data_preprocessor_lstm.pkl'), 'rb') as f:
    data_preprocessor_lstm = pickle.load(f)

#residual lightgbm
train_lightgbm_residuals_df = pd.read_csv(os.path.join(config.output_cleaned_hybrid, f'lightgbm_lstm/{variant_co2}/residuals_train.csv')).set_index(["year", "country"]).rename_axis(index={"country": config.additional_index})
test_lightgbm_residuals_df = pd.read_csv(os.path.join(config.output_cleaned_hybrid, f'lightgbm_lstm/{variant_co2}/residuals_test.csv')).set_index(["year", "country"]).rename_axis(index={"country": config.additional_index})
train_lightgbm_residuals_preprocessed, test_lightgbm_residuals_preprocessed = data_preprocessor_lstm.preprocess_data(train_lightgbm_residuals_df, test_lightgbm_residuals_df)

# %%
train_lstm_df
# Out:
#                         country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1853 Stany Zjednoczone           34        0.016985  0.078879
# 1854 Stany Zjednoczone           34        0.017544  0.083750
# 1855 Stany Zjednoczone           34        0.018120  0.090790
# 1856 Stany Zjednoczone           34        0.018712  0.090836
# 1857 Stany Zjednoczone           34        0.019322  0.088710
# ...                             ...             ...       ...
# 1996 Szwecja                     35        0.005112  0.633681
# 1997 Szwecja                     35        0.005147  0.657400
# 1998 Szwecja                     35        0.005158  0.668932
# 1999 Szwecja                     35        0.005162  0.688825
# 2000 Szwecja                     35        0.005166  0.719798
#
#                         temperature_change_from_co2_t-2  total_ghg_t-2  \
# year country_index
# 1853 Stany Zjednoczone                         0.000000       0.809861
# 1854 Stany Zjednoczone                         0.054411       0.826034
# 1855 Stany Zjednoczone                         0.052824       0.807592
# 1856 Stany Zjednoczone                         0.102565       0.813081
# 1857 Stany Zjednoczone                         0.099573       0.799701
# ...                                                 ...            ...
# 1996 Szwecja                                   0.310355       0.169580
# 1997 Szwecja                                   0.308734       0.176222
# 1998 Szwecja                                   0.308244       0.184783
# 1999 Szwecja                                   0.308063       0.176055
# 2000 Szwecja                                   0.307886       0.178449
#
#                         cement_co2_t-2  coal_co2_t-2  flaring_co2_t-2  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.065960         0.000000
# 1854 Stany Zjednoczone        0.000000      0.069644         0.000000
# 1855 Stany Zjednoczone        0.000000      0.076120         0.000000
# 1856 Stany Zjednoczone        0.000000      0.081242         0.000000
# 1857 Stany Zjednoczone        0.000000      0.090770         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.160121      0.083308         0.001888
# 1997 Szwecja                  0.186143      0.082777         0.002145
# 1998 Szwecja                  0.175666      0.091217         0.002047
# 1999 Szwecja                  0.158365      0.079360         0.002274
# 2000 Szwecja                  0.162285      0.081697         0.002317
#
#                         gas_co2_t-2  land_use_change_co2_t-2  ...   gdp_t-1  \
# year country_index                                            ...
# 1853 Stany Zjednoczone     0.000000                 0.489399  ...  0.083750
# 1854 Stany Zjednoczone     0.000000                 0.501986  ...  0.090790
# 1855 Stany Zjednoczone     0.000000                 0.494294  ...  0.090836
# 1856 Stany Zjednoczone     0.000000                 0.498800  ...  0.088710
# 1857 Stany Zjednoczone     0.000000                 0.491227  ...  0.090730
# ...                             ...                      ...  ...       ...
# 1996 Szwecja               0.034710                 0.056927  ...  0.657400
# 1997 Szwecja               0.035107                 0.062237  ...  0.668932
# 1998 Szwecja               0.037824                 0.059806  ...  0.688825
# 1999 Szwecja               0.038312                 0.061110  ...  0.719798
# 2000 Szwecja               0.037882                 0.062093  ...  0.755299
#
#                         temperature_change_from_co2_t-1  total_ghg_t-1  \
# year country_index
# 1853 Stany Zjednoczone                         0.054411       0.826034
# 1854 Stany Zjednoczone                         0.052824       0.807592
# 1855 Stany Zjednoczone                         0.102565       0.813081
# 1856 Stany Zjednoczone                         0.099573       0.799701
# 1857 Stany Zjednoczone                         0.096669       0.799440
# ...                                                 ...            ...
# 1996 Szwecja                                   0.308734       0.176222
# 1997 Szwecja                                   0.308244       0.184783
# 1998 Szwecja                                   0.308063       0.176055
# 1999 Szwecja                                   0.307886       0.178449
# 2000 Szwecja                                   0.307640       0.169071
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone        0.000000      0.069644         0.000000
# 1854 Stany Zjednoczone        0.000000      0.076120         0.000000
# 1855 Stany Zjednoczone        0.000000      0.081242         0.000000
# 1856 Stany Zjednoczone        0.000000      0.090770         0.000000
# 1857 Stany Zjednoczone        0.000000      0.092454         0.000000
# ...                                ...           ...              ...
# 1996 Szwecja                  0.176169      0.082777         0.002145
# 1997 Szwecja                  0.166254      0.091217         0.002047
# 1998 Szwecja                  0.149879      0.079360         0.002274
# 1999 Szwecja                  0.153589      0.081697         0.002317
# 2000 Szwecja                  0.154279      0.073842         0.002379
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1853 Stany Zjednoczone     0.000000                 0.501986     0.000000
# 1854 Stany Zjednoczone     0.000000                 0.494294     0.000000
# 1855 Stany Zjednoczone     0.000000                 0.498800     0.000000
# 1856 Stany Zjednoczone     0.000000                 0.491227     0.000000
# 1857 Stany Zjednoczone     0.000000                 0.491663     0.000000
# ...                             ...                      ...          ...
# 1996 Szwecja               0.035107                 0.062237     0.286368
# 1997 Szwecja               0.037824                 0.059806     0.302837
# 1998 Szwecja               0.038312                 0.061110     0.280898
# 1999 Szwecja               0.037882                 0.062093     0.280912
# 2000 Szwecja               0.036850                 0.058259     0.269514
#
#                              co2
# year country_index
# 1853 Stany Zjednoczone  0.495427
# 1854 Stany Zjednoczone  0.500984
# 1855 Stany Zjednoczone  0.495014
# 1856 Stany Zjednoczone  0.495772
# 1857 Stany Zjednoczone  0.488626
# ...                          ...
# 1996 Szwecja            0.123911
# 1997 Szwecja            0.118362
# 1998 Szwecja            0.119892
# 1999 Szwecja            0.112061
# 2000 Szwecja            0.117745
#
# [3153 rows x 23 columns]

# %%
train_lightgbm_residuals_preprocessed
# Out:
#                        residual
# year country_index
# 1961 Arabia Saudyjska  0.265942
# 1962 Arabia Saudyjska  0.270581
# 1963 Arabia Saudyjska  0.229383
# 1964 Arabia Saudyjska  0.235566
# 1965 Arabia Saudyjska  0.209027
# ...                         ...
# 2000 Włochy            0.263503
# 2001 Włochy            0.260255
# 2002 Włochy            0.264362
# 2003 Włochy            0.267271
# 2004 Włochy            0.266029
#
# [3153 rows x 1 columns]

# %%
#combine train df
train_hybrid_df = pd.merge(train_lightgbm_residuals_preprocessed, train_lstm_df, left_index=True, right_index=True)
train_hybrid_df
# Out:
#                        residual  country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1961 Arabia Saudyjska  0.265942            0        0.000194  0.243528
# 1962 Arabia Saudyjska  0.270581            0        0.000261  0.258822
# 1963 Arabia Saudyjska  0.229383            0        0.000331  0.279879
# 1964 Arabia Saudyjska  0.235566            0        0.000403  0.302746
# 1965 Arabia Saudyjska  0.209027            0        0.000478  0.317662
# ...                         ...          ...             ...       ...
# 2000 Włochy            0.263503           44        0.042144  0.703614
# 2001 Włochy            0.260255           44        0.042163  0.719492
# 2002 Włochy            0.264362           44        0.042187  0.751454
# 2003 Włochy            0.267271           44        0.042213  0.770000
# 2004 Włochy            0.266029           44        0.042301  0.776193
#
#                        temperature_change_from_co2_t-2  total_ghg_t-2  \
# year country_index
# 1961 Arabia Saudyjska                         0.000000       0.042250
# 1962 Arabia Saudyjska                         0.000000       0.058532
# 1963 Arabia Saudyjska                         0.000000       0.082953
# 1964 Arabia Saudyjska                         0.000000       0.144590
# 1965 Arabia Saudyjska                         0.000000       0.156866
# ...                                                ...            ...
# 2000 Włochy                                   0.166694       0.191990
# 2001 Włochy                                   0.166619       0.191157
# 2002 Włochy                                   0.190318       0.191894
# 2003 Włochy                                   0.190206       0.188632
# 2004 Włochy                                   0.189826       0.190118
#
#                        cement_co2_t-2  coal_co2_t-2  flaring_co2_t-2  \
# year country_index
# 1961 Arabia Saudyjska        0.019437      0.000000         0.000000
# 1962 Arabia Saudyjska        0.022903      0.000000         0.000000
# 1963 Arabia Saudyjska        0.025592      0.000000         0.000000
# 1964 Arabia Saudyjska        0.044016      0.000000         0.000000
# 1965 Arabia Saudyjska        0.045686      0.000000         0.000000
# ...                               ...           ...              ...
# 2000 Włochy                  0.322117      0.062423         0.003817
# 2001 Włochy                  0.338340      0.061341         0.003052
# 2002 Włochy                  0.351103      0.063685         0.003200
# 2003 Włochy                  0.362667      0.067046         0.003011
# 2004 Włochy                  0.359623      0.068037         0.002782
#
#                        gas_co2_t-2  ...   gdp_t-1  \
# year country_index                  ...
# 1961 Arabia Saudyjska     0.000000  ...  0.258822
# 1962 Arabia Saudyjska     0.000000  ...  0.279879
# 1963 Arabia Saudyjska     0.000000  ...  0.302746
# 1964 Arabia Saudyjska     0.001262  ...  0.317662
# 1965 Arabia Saudyjska     0.001603  ...  0.333562
# ...                            ...  ...       ...
# 2000 Włochy               0.311536  ...  0.719492
# 2001 Włochy               0.338965  ...  0.751454
# 2002 Włochy               0.353906  ...  0.770000
# 2003 Włochy               0.354470  ...  0.776193
# 2004 Włochy               0.355745  ...  0.779291
#
#                        temperature_change_from_co2_t-1  total_ghg_t-1  \
# year country_index
# 1961 Arabia Saudyjska                         0.000000       0.058532
# 1962 Arabia Saudyjska                         0.000000       0.082953
# 1963 Arabia Saudyjska                         0.000000       0.144590
# 1964 Arabia Saudyjska                         0.000000       0.156866
# 1965 Arabia Saudyjska                         0.000000       0.153435
# ...                                                ...            ...
# 2000 Włochy                                   0.166619       0.191157
# 2001 Włochy                                   0.190318       0.191894
# 2002 Włochy                                   0.190206       0.188632
# 2003 Włochy                                   0.189826       0.190118
# 2004 Włochy                                   0.188777       0.196087
#
#                        cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1961 Arabia Saudyjska        0.021676      0.000000         0.000000
# 1962 Arabia Saudyjska        0.024220      0.000000         0.000000
# 1963 Arabia Saudyjska        0.041657      0.000000         0.000000
# 1964 Arabia Saudyjska        0.043238      0.000000         0.000000
# 1965 Arabia Saudyjska        0.053995      0.000000         0.000000
# ...                               ...           ...              ...
# 2000 Włochy                  0.320211      0.061341         0.003052
# 2001 Włochy                  0.332290      0.063685         0.003200
# 2002 Włochy                  0.343234      0.067046         0.003011
# 2003 Włochy                  0.340353      0.068037         0.002782
# 2004 Włochy                  0.351958      0.073421         0.003293
#
#                        gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1961 Arabia Saudyjska     0.000000                 0.071374     0.062017
# 1962 Arabia Saudyjska     0.000000                 0.072538     0.079918
# 1963 Arabia Saudyjska     0.001262                 0.073308     0.134421
# 1964 Arabia Saudyjska     0.001603                 0.074590     0.143784
# 1965 Arabia Saudyjska     0.065958                 0.074268     0.115466
# ...                            ...                      ...          ...
# 2000 Włochy               0.338965                 0.063718     0.260213
# 2001 Włochy               0.353906                 0.062837     0.255294
# 2002 Włochy               0.354470                 0.061673     0.251337
# 2003 Włochy               0.355745                 0.060207     0.256716
# 2004 Włochy               0.388044                 0.061331     0.253608
#
#                             co2
# year country_index
# 1961 Arabia Saudyjska  0.067313
# 1962 Arabia Saudyjska  0.079858
# 1963 Arabia Saudyjska  0.083187
# 1964 Arabia Saudyjska  0.082177
# 1965 Arabia Saudyjska  0.069495
# ...                         ...
# 2000 Włochy            0.139462
# 2001 Włochy            0.138231
# 2002 Włochy            0.138098
# 2003 Włochy            0.142459
# 2004 Włochy            0.142448
#
# [3153 rows x 24 columns]

# %%
#combine test df
test_hybrid_df = pd.merge(test_lightgbm_residuals_preprocessed, test_lstm_df, left_index=True, right_index=True)
test_hybrid_df
# Out:
#                         residual  country_t-2  population_t-2   gdp_t-2  \
# year country_index
# 1989 Stany Zjednoczone  0.282597           34        0.186605  0.791559
# 1990 Stany Zjednoczone  0.278180           34        0.188312  0.817759
# 1991 Stany Zjednoczone  0.264603           34        0.190056  0.838605
# 1992 Stany Zjednoczone  0.275247           34        0.192119  0.844259
# 1993 Stany Zjednoczone  0.279643           34        0.194488  0.831598
# ...                          ...          ...             ...       ...
# 2019 Szwecja            0.238870           35        0.006089  1.034912
# 2020 Szwecja            0.236938           35        0.006179  1.042982
# 2021 Szwecja            0.254316           35        0.006258  1.053059
# 2022 Szwecja            0.248389           35        0.006315  1.022503
# 2023 Szwecja            0.244419           35        0.006363  1.071581
#
#                         temperature_change_from_co2_t-2  total_ghg_t-2  \
# year country_index
# 1989 Stany Zjednoczone                         0.846847       0.508303
# 1990 Stany Zjednoczone                         0.850208       0.524219
# 1991 Stany Zjednoczone                         0.853340       0.526559
# 1992 Stany Zjednoczone                         0.860384       0.518755
# 1993 Stany Zjednoczone                         0.860616       0.506536
# ...                                                 ...            ...
# 2019 Szwecja                                   0.406395       0.152356
# 2020 Szwecja                                   0.401701       0.146722
# 2021 Szwecja                                   0.397648       0.142694
# 2022 Szwecja                                   0.394784       0.133416
# 2023 Szwecja                                   0.392417       0.138824
#
#                         cement_co2_t-2  coal_co2_t-2  flaring_co2_t-2  \
# year country_index
# 1989 Stany Zjednoczone        0.169824      0.452087         0.001514
# 1990 Stany Zjednoczone        0.169686      0.469840         0.001729
# 1991 Stany Zjednoczone        0.168223      0.470866         0.001702
# 1992 Stany Zjednoczone        0.167532      0.466174         0.010276
# 1993 Stany Zjednoczone        0.161811      0.456131         0.009935
# ...                                ...           ...              ...
# 2019 Szwecja                  0.187046      0.053815         0.004475
# 2020 Szwecja                  0.200210      0.051773         0.004556
# 2021 Szwecja                  0.167357      0.051390         0.002930
# 2022 Szwecja                  0.155745      0.041803         0.002415
# 2023 Szwecja                  0.153229      0.043696         0.000049
#
#                         gas_co2_t-2  ...   gdp_t-1  \
# year country_index                   ...
# 1989 Stany Zjednoczone     0.563915  ...  0.817759
# 1990 Stany Zjednoczone     0.583915  ...  0.838605
# 1991 Stany Zjednoczone     0.616149  ...  0.844259
# 1992 Stany Zjednoczone     0.607288  ...  0.831598
# 1993 Stany Zjednoczone     0.611097  ...  0.850993
# ...                             ...  ...       ...
# 2019 Szwecja               0.027086  ...  1.042982
# 2020 Szwecja               0.027867  ...  1.053059
# 2021 Szwecja               0.026035  ...  1.022503
# 2022 Szwecja               0.020940  ...  1.071581
# 2023 Szwecja               0.027439  ...  1.092619
#
#                         temperature_change_from_co2_t-1  total_ghg_t-1  \
# year country_index
# 1989 Stany Zjednoczone                         0.850208       0.524219
# 1990 Stany Zjednoczone                         0.853340       0.526559
# 1991 Stany Zjednoczone                         0.860384       0.518755
# 1992 Stany Zjednoczone                         0.860616       0.506536
# 1993 Stany Zjednoczone                         0.860721       0.509469
# ...                                                 ...            ...
# 2019 Szwecja                                   0.401701       0.146722
# 2020 Szwecja                                   0.397648       0.142694
# 2021 Szwecja                                   0.394784       0.133416
# 2022 Szwecja                                   0.392417       0.138824
# 2023 Szwecja                                   0.389753       0.133445
#
#                         cement_co2_t-1  coal_co2_t-1  flaring_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone        0.160594      0.469840         0.001729
# 1990 Stany Zjednoczone        0.159209      0.470866         0.001702
# 1991 Stany Zjednoczone        0.158555      0.466174         0.010276
# 1992 Stany Zjednoczone        0.153140      0.456131         0.009935
# 1993 Stany Zjednoczone        0.152479      0.455670         0.009743
# ...                                ...           ...              ...
# 2019 Szwecja                  0.189482      0.051773         0.004556
# 2020 Szwecja                  0.158390      0.051390         0.002930
# 2021 Szwecja                  0.147399      0.041803         0.002415
# 2022 Szwecja                  0.145018      0.043696         0.000049
# 2023 Szwecja                  0.144034      0.042915         0.000064
#
#                         gas_co2_t-1  land_use_change_co2_t-1  oil_co2_t-1  \
# year country_index
# 1989 Stany Zjednoczone     0.583915                 0.082995     0.517934
# 1990 Stany Zjednoczone     0.616149                 0.082725     0.512904
# 1991 Stany Zjednoczone     0.607288                 0.083405     0.493612
# 1992 Stany Zjednoczone     0.611097                 0.080776     0.474745
# 1993 Stany Zjednoczone     0.625705                 0.078382     0.480823
# ...                             ...                      ...          ...
# 2019 Szwecja               0.027867                 0.075373     0.164163
# 2020 Szwecja               0.026035                 0.075950     0.159296
# 2021 Szwecja               0.020940                 0.076321     0.146172
# 2022 Szwecja               0.027439                 0.077285     0.154059
# 2023 Szwecja               0.022221                 0.077701     0.142306
#
#                              co2
# year country_index
# 1989 Stany Zjednoczone  0.308212
# 1990 Stany Zjednoczone  0.305718
# 1991 Stany Zjednoczone  0.297345
# 1992 Stany Zjednoczone  0.297198
# 1993 Stany Zjednoczone  0.298140
# ...                          ...
# 2019 Szwecja            0.101755
# 2020 Szwecja            0.096965
# 2021 Szwecja            0.099935
# 2022 Szwecja            0.098720
# 2023 Szwecja            0.097622
#
# [816 rows x 24 columns]

# %% [markdown]
# ## Reshape the data

# %%
data_resherper = DataReshaperLSTM()
x_train, x_test, y_train, y_test = data_resherper.reshape_data(train_hybrid_df, test_hybrid_df)

# %% [markdown]
# ## Build the model

# %%
input_shape = (x_train.shape[1], x_train.shape[2])
output_units = 1

model = Sequential([
    LSTM(50, input_shape=input_shape, return_sequences = True),
    Dropout(0.2),
    LSTM(50),
    Dropout(0.2),
    Dense(output_units, activation='relu')
])

model.compile(optimizer="adam", loss="mean_squared_error")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 50)             14800
#
#  dropout (Dropout)           (None, 1, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 35,051
# Trainable params: 35,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(x_train, y_train, epochs=config.epochs, batch_size=config.batch_size)
# Out:
# Epoch 1/15
# 3153/3153 [==============================] - 3s 725us/step - loss: 0.0053
# Epoch 2/15
# 3153/3153 [==============================] - 3s 884us/step - loss: 0.0024
# Epoch 3/15
# 3153/3153 [==============================] - 2s 690us/step - loss: 0.0021
# Epoch 4/15
# 3153/3153 [==============================] - 2s 687us/step - loss: 0.0020
# Epoch 5/15
# 3153/3153 [==============================] - 2s 697us/step - loss: 0.0016
# Epoch 6/15
# 3153/3153 [==============================] - 3s 864us/step - loss: 0.0015
# Epoch 7/15
# 3153/3153 [==============================] - 2s 677us/step - loss: 0.0015
# Epoch 8/15
# 3153/3153 [==============================] - 2s 667us/step - loss: 0.0014
# Epoch 9/15
# 3153/3153 [==============================] - 2s 726us/step - loss: 0.0013
# Epoch 10/15
# 3153/3153 [==============================] - 2s 712us/step - loss: 0.0010
# Epoch 11/15
# 3153/3153 [==============================] - 2s 688us/step - loss: 0.0012
# Epoch 12/15
# 3153/3153 [==============================] - 2s 676us/step - loss: 0.0010
# Epoch 13/15
# 3153/3153 [==============================] - 2s 711us/step - loss: 0.0012
# Epoch 14/15
# 3153/3153 [==============================] - 2s 675us/step - loss: 0.0010
# Epoch 15/15
# 3153/3153 [==============================] - 2s 696us/step - loss: 9.3517e-04

# %%
# Save the model
model.save(os.path.join(config.models_folder, f'{variant_co2}_lightgbm_lstm_model.h5'))

# Evaluate the model on the test set
loss = model.evaluate(x_test, y_test, verbose = 0)

# %% [markdown]
# ## Predictions

# %%
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)

inverted_data_predicted_train_y = data_preprocessor_lstm.inverse_transform_data(train_predictions, train_predictions.shape[0], train_hybrid_df.shape[1]-2)
inverted_data_train_y = data_preprocessor_lstm.inverse_transform_data(y_train, train_predictions.shape[0], train_hybrid_df.shape[1]-2)

inverted_data_predicted_test_y = data_preprocessor_lstm.inverse_transform_data(test_predictions, test_predictions.shape[0], test_hybrid_df.shape[1]-2)
inverted_data_test_y = data_preprocessor_lstm.inverse_transform_data(y_test, test_predictions.shape[0], test_hybrid_df.shape[1]-2)
# Out:
# 99/99 [==============================] - 0s 420us/step
# 26/26 [==============================] - 0s 434us/step

# %%
train_df_reset = train_hybrid_df.reset_index()
test_df_reset = test_hybrid_df.reset_index()

co2_predicted_train = inverted_data_predicted_train_y[:, -1]
co2_actual_train = inverted_data_train_y[:, -1]
co2_predicted_test = inverted_data_predicted_test_y[:, -1]
co2_actual_test = inverted_data_test_y[:, -1]

# Create DataFrames for train and test
train_results = pd.DataFrame({
    "country": train_df_reset["country_index"].values,
    "year": train_df_reset["year"].values,
    "co2_predicted": co2_predicted_train,
    "co2_actual": co2_actual_train
})

test_results = pd.DataFrame({
    "country": test_df_reset["country_index"].values,
    "year": test_df_reset["year"].values,
    "co2_predicted": co2_predicted_test,
    "co2_actual": co2_actual_test
})


train_results.to_csv(os.path.join(config.predictions_hybrid_lightgbm_lstm, f'lightgbm_lstm_{variant_co2}_train.csv'))
test_results.to_csv(os.path.join(config.predictions_hybrid_lightgbm_lstm, f'lightgbm_lstm_{variant_co2}_test.csv'))

# %% [markdown]
# ## Charts

# %%
charts = ModelCharts(train_results, test_results)

#Line plot
charts.generate_line_plot(variant = variant_co2, model_output_file=config.predictions_hybrid_lightgbm_lstm)
charts.generate_line_plot_one_dataset(variant = variant_co2, model_output_file=config.predictions_hybrid_lightgbm_lstm, dataset_type='train')
charts.generate_line_plot_one_dataset(variant = variant_co2, model_output_file=config.predictions_hybrid_lightgbm_lstm, dataset_type='test')

#Scatter plot
charts.generate_scatter_plot(variant = variant_co2, model_output_file=config.predictions_hybrid_lightgbm_lstm)
charts.generate_scatter_plot_one_dataset(variant = variant_co2, model_output_file=config.predictions_hybrid_lightgbm_lstm, dataset_type='train')
charts.generate_scatter_plot_one_dataset(variant = variant_co2, model_output_file=config.predictions_hybrid_lightgbm_lstm, dataset_type='test')

# %% [markdown]
# ## Metrics

# %%
evaluator = PredictionEvaluator()
evaluator.evaluate(train_results, test_results, actual_col='co2_actual', predicted_col='co2_predicted', variant = f'lightgbm_lstm_{variant_co2}', model_output_file=config.metrics_hybrid)
